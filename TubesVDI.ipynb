# %% [markdown]
# <a href="https://colab.research.google.com/github/diosamuel/checkin-spatial-analysis/blob/main/TubesVDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
NYC = pd.read_csv("https://raw.githubusercontent.com/diosamuel/checkin-spatial-analysis/refs/heads/main/dataset/dataset_TSMC2014_NYC.csv")
TKY = pd.read_csv("https://raw.githubusercontent.com/diosamuel/checkin-spatial-analysis/refs/heads/main/dataset/dataset_TSMC2014_TKY.csv")

# %% [markdown]
# # Cek Missing Value

# %%
print("NYC")
print(NYC.isnull().sum())
print("TKY")
print(TKY.isnull().sum())
# Out:
# NYC
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64
# TKY
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64

# %% [markdown]
# ## Ubah VenueID ke nama tempat butuh api dari Foursquare
#
# dikasih \$200 dollar tiap bulan
#
# sekali hit api = $000.01 dollar

# %%
NYC.iloc[1]
# Out:
# userId                                        979
# venueId                  4a43c0aef964a520c6a61fe3
# venueCategoryId          4bf58dd8d48988d1df941735
# venueCategory                              Bridge
# latitude                                  40.6068
# longitude                               -74.04417
# timezoneOffset                               -240
# utcTimestamp       Tue Apr 03 18:00:25 +0000 2012
# Name: 1, dtype: object

# %%
import requests
venueId = "4a43c0aef964a520c6a61fe3"
versioning = "%2020231010"
oauth_token = "URKT0K1X0DOFMRKYKKYVVPGI1GIWVBRFCTP005RJFH1JKS0C"
url = f"https://api.foursquare.com/v2/venues/{venueId}/?v={versioning}&oauth_token={oauth_token}"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"meta":{"code":200,"requestId":"6745ad68dd7c9c5138e929a5"},"notifications":[{"type":"notificationTray","item":{"unreadCount":0}}],"response":{"venue":{"id":"4a43c0aef964a520c6a61fe3","name":"Verrazzano-Narrows Bridge","contact":{},"location":{"address":"Brooklyn\/Staten Island","crossStreet":"I-278","lat":40.605405,"lng":-74.048466,"labeledLatLngs":[{"label":"display","lat":40.605405,"lng":-74.048466}],"radius50":1365,"radius90":3217,"postalCode":"10305","cc":"US","city":"Brooklyn","state":"NY","country":"United States","formattedAddress":["Brooklyn\/Staten Island (I-278)","Brooklyn, NY 10305","United States"]},"canonicalUrl":"https:\/\/foursquare.com\/v\/verrazanonarrows-bridge\/4a43c0aef964a520c6a61fe3","categories":[{"id":"4bf58dd8d48988d1df941735","name":"Bridge","pluralName":"Bridges","shortName":"Bridge","icon":{"prefix":"https:\/\/ss3.4sqi.net\/img\/categories_v2\/parks_outdoors\/bridge_","suffix":".png"},"categoryCode":16006,"mapIcon":"fsq-default","primary":true}],"verified
# ...

# %%
example = """
{"meta":{"code":200,"requestId":"6745ac98f9fc4667f6800674"},"notifications":[{"type":"notificationTray","item":{"unreadCount":0}}],"response":{"venue":{"id":"49bbd6c0f964a520f4531fe3","name":"Pearl Art & Craft Supply","contact":{"phone":"2124317932","formattedPhone":"(212) 431-7932","twitter":"pearlpaint"},"location":{"address":"308 Canal St","crossStreet":"btwn Broadway & Mercer","lat":40.719726415811074,"lng":-74.00247199946715,"radius50":32,"radius90":244,"postalCode":"10013","cc":"US","city":"New York","state":"NY","country":"United States","formattedAddress":["308 Canal St (btwn Broadway & Mercer)","New York, NY 10013","United States"]},"canonicalUrl":"https:\/\/foursquare.com\/v\/pearl-art--craft-supply\/49bbd6c0f964a520f4531fe3","categories":[{"id":"4bf58dd8d48988d127951735","name":"Arts and Crafts Store","pluralName":"Arts and Crafts Stores","shortName":"Arts and Crafts Store","icon":{"prefix":"https:\/\/ss3.4sqi.net\/img\/categories_v2\/shops\/artstore_","suffix":".png"},"categoryCode":17003,"mapIcon":"fsq-default","primary":true}],"verified":false,"stats":{"tipCount":36},"closed":true,"url":"http:\/\/www.pearlpaint.com","likes":{"count":72,"groups":[{"type":"others","count":72,"items":[]}],"summary":"72 Likes"},"like":false,"dislike":false,"ok":false,"header":"This place doesn't have a rating yet. Once more members of the Foursquare community visit, we can calculate a rating.","explanation":"We take into account visits and input from our community. You'll see a number on places based off of ratings and tips written by people like you.","allowMenuUrlEdit":true,"beenHere":{"count":0,"unconfirmedCount":0,"marked":false,"lastCheckinExpiredAt":0},"photos":{"count":82,"groups":[{"type":"venue","name":"Venue photos","count":82,"items":[{"id":"51c75718498e56304ff11a23","createdAt":1372018456,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/2874027_ur6Qbbwyv9k91b3eoUgXfiwj_JF0197YcGq-Zi3-Uqg.jpg","width":720,"height":960,"user":{"id":"2874027","firstName":"Zeb","lastName":"Holt","handle":"zebulonholt","privateProfile":false,"gender":"male","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/H01V5PRGAJFJMD2K.jpg"}},"visibility":"public"},{"id":"51f03cbf498e6ec7106397c6","createdAt":1374698687,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/2870905_k7r9D8mILFmHjD93n5fNqKVPXlCQGeRmmGFLkF-FOyQ.jpg","width":720,"height":960,"user":{"id":"2870905","firstName":"John","lastName":"Proano","handle":"johnproano","privateProfile":false,"gender":"male","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/VE4NVEQCGI3OIWGQ.jpg"}},"visibility":"public"},{"id":"5102aaa8e4b0b319975b4d7c","createdAt":1359129256,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/39399943_gXAWIy8HD-xx2tzxsuelgJP236IAZPQJRP9l9LeHLKM.jpg","width":720,"height":960,"user":{"id":"39399943","firstName":"AndresT5","handle":"andrest53699722","privateProfile":false,"gender":"male","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/0GNATKB1CBETNABQ.jpg"}},"visibility":"public"},{"id":"4dcec7fffd28e64f60f40fd3","createdAt":1305397247,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/MDFU55TIZ0AQVMNQDMIUVRRVPOJB2V20IWHWIH3E1XO5RBD5.jpg","width":537,"height":720,"user":{"id":"229","firstName":"Rick","lastName":"Webb","handle":"rickwebb","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/_1234222635.jpg"}},"visibility":"public"}]}]},"reasons":{"count":1,"items":[{"summary":"Lots of people like this place","type":"general","reasonName":"rawLikesReason"}]},"createdAt":1237046976,"hereNow":{"count":0,"summary":"Nobody here","groups":[]},"tips":{"count":36,"groups":[{"type":"following","name":"Tips from people you follow","count":0,"items":[]},{"type":"others","name":"All tips","count":36,"items":[{"id":"4d961646d1bca090785655b4","createdAt":1301681734,"text":"Five floors of art supply heaven \u2013 they have absolutely everything! And the helpful staff will assist you in find everything on your list. Students get 10% off their order.","type":"user","canonicalUrl":"https:\/\/foursquare.com\/item\/4d961646d1bca090785655b4","likes":{"count":32,"groups":[{"type":"others","count":32,"items":[]}],"summary":"32 likes"},"like":false,"logView":true,"agreeCount":4,"disagreeCount":0,"todo":{"count":3},"user":{"id":"95423","firstName":"The Corcoran Group","handle":"corcoran_group","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/95423-FGRZ1IMU5FZQMCZB.jpg"},"type":"page"}},{"id":"49bbd6d770c603bbc3108eb4","createdAt":1237046999,"text":"The art store has 5 floors: boxes, bags, inks, portfolios - paints, brushes, pastels - paper, sketchbooks, acetate - air brushes, light boxes and more..","type":"user","canonicalUrl":"https:\/\/foursquare.com\/item\/49bbd6d770c603bbc3108eb4","likes":{"count":10,"groups":[{"type":"others","count":10,"items":[]}],"summary":"10 likes"},"like":false,"logView":true,"agreeCount":2,"disagreeCount":0,"todo":{"count":1},"user":{"id":"1726","firstName":"adafruit","lastName":"fried & torrone","handle":"adafruit","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/1726_1236972007.jpg"}}},{"id":"4fe0de79e4b0bd44612a99d5","createdAt":1340137081,"text":"In the heart of NYC\u2019s Chinatown, Pearl has everything an artist or crafter needs to create! \u2013 Meg Paska","type":"user","canonicalUrl":"https:\/\/foursquare.com\/item\/4fe0de79e4b0bd44612a99d5","likes":{"count":5,"groups":[{"type":"others","count":5,"items":[{"id":"57942091","firstName":"eth","handle":"eth9200322","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"DE","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"}},{"id":"33403266","firstName":"Justine","handle":"tinaroy59","privateProfile":false,"gender":"female","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/HUQJMDBOLG24V0HF.jpg"}},{"id":"126884","firstName":"danielle","handle":"danielleabes","privateProfile":false,"gender":"female","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/NM5VE4RU52MTFQKE.jpg"}},{"id":"43910248","firstName":"Rachel","lastName":"Faucett","handle":"followcharlotte","privateProfile":false,"gender":"female","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/4UNOTPJUIFKROTYS.jpg"}}]}],"summary":"5 likes"},"like":false,"logView":true,"agreeCount":5,"disagreeCount":0,"todo":{"count":2},"user":{"id":"1596715","firstName":"Bing","handle":"bing","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/ZVCLYGVA33EMBIYB.jpg"},"type":"page"}},{"id":"4ed7b1d0be7b356716f5cf14","createdAt":1322758608,"text":"Go to Pearl Paint, pick up some watercolors, take a walk to Battery Park and paint the skyline, Lady Liberty and Ellis Island as boats sail by.","type":"user","canonicalUrl":"https:\/\/foursquare.com\/item\/4ed7b1d0be7b356716f5cf14","photo":{"id":"4ed7b1d1a17c6e17b5ea8298","createdAt":1322758609,"source":{"name":"Foursquare Web","url":"https:\/\/foursquare.com"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg","width":450,"height":373,"visibility":"public"},"photos":[{"id":"4ed7b1d1a17c6e17b5ea8298","createdAt":1322758609,"source":{"name":"Foursquare Web","url":"https:\/\/foursquare.com"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg","width":450,"height":373,"visibility":"public"}],"photourl":"https:\/\/fastly.4sqi.net\/img\/general\/original\/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg","likes":{"count":5,"groups":[{"type":"others","count":5,"items":[{"id":"49936356","firstName":"Budak","lastName":"Pokan💂","handle":"budak1463236","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"SG","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/49936356_d7tEwjIa_DmddEssVOIg01esf1ZewuXpz5x1Y6GqxAot0fJjl4Xh8cUULyiV-U0Z408O8waSm.jpg"}},{"id":"36834369","firstName":"Cman","lastName":"Finn","handle":"cman_0412","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"MY","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/36834369-SMLGRYWE1N1IAESS.jpg"}},{"id":"57942091","firstName":"eth","handle":"eth9200322","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"DE","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"}},{"id":"38387096","firstName":"\"Tee Coleman\"","handle":"teecolem6886202","privateProfile":false,"gender":"female","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/5RW3XBKXWMBDNLGF.jpg"}}]}],"summary":"5 likes"},"like":false,"logView":true,"agreeCount":5,"disagreeCount":0,"todo":{"count":10},"user":{"id":"337548","firstName":"Lucky Magazine","handle":"luckymag","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/K5LCPOAUKWFOMV0X.jpg"},"type":"page"}}]}]},"shortUrl":"http:\/\/4sq.com\/2UcSiI","timeZone":"America\/New_York","listed":{"count":83,"groups":[{"type":"others","name":"Lists from other people","count":83,"items":[{"id":"4ed7a30f29c216b5c8d05810","name":"Sophie's Favorite Holiday Spots in NYC","description":"The Super Adventures of Sophie and the City by Kelly Florio Kasouf is a children's book about Kasouf's childhood growing up in the halls of Conde Nast. She picked her favorite holiday spots to visit.","type":"others","user":{"id":"337548","firstName":"Lucky Magazine","handle":"luckymag","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/K5LCPOAUKWFOMV0X.jpg"},"type":"page"},"editable":false,"public":true,"collaborative":false,"url":"\/luckymag\/list\/sophies-favorite-holiday-spots-in-nyc","canonicalUrl":"https:\/\/foursquare.com\/luckymag\/list\/sophies-favorite-holiday-spots-in-nyc","createdAt":1322754831,"updatedAt":1377042169,"photo":{"id":"4ed7accda17c6e17b5e9ccef","createdAt":1322757325,"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/HPCHEWUSIBU4CPJGQQPZWZPOBF2SKP30KECLIX0T0NG043AV.jpg","width":366,"height":465,"user":{"id":"337548","firstName":"Lucky Magazine","handle":"luckymag","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/K5LCPOAUKWFOMV0X.jpg"},"type":"page"},"visibility":"public"},"logView":true,"followers":{"count":194},"listItems":{"count":22,"items":[{"id":"t4ed7b1d0be7b356716f5cf14","createdAt":1322755445,"tip":{"id":"4ed7b1d0be7b356716f5cf14","createdAt":1322758608,"text":"Go to Pearl Paint, pick up some watercolors, take a walk to Battery Park and paint the skyline, Lady Liberty and Ellis Island as boats sail by.","type":"user","canonicalUrl":"https:\/\/foursquare.com\/item\/4ed7b1d0be7b356716f5cf14","likes":{"count":5,"groups":[{"type":"others","count":5,"items":[{"id":"49936356","firstName":"Budak","lastName":"Pokan💂","handle":"budak1463236","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"SG","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/49936356_d7tEwjIa_DmddEssVOIg01esf1ZewuXpz5x1Y6GqxAot0fJjl4Xh8cUULyiV-U0Z408O8waSm.jpg"}},{"id":"36834369","firstName":"Cman","lastName":"Finn","handle":"cman_0412","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"MY","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/36834369-SMLGRYWE1N1IAESS.jpg"}},{"id":"57942091","firstName":"eth","handle":"eth9200322","privateProfile":false,"gender":"male","address":"","city":"","state":"","countryCode":"DE","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"}},{"id":"38387096","firstName":"\"Tee Coleman\"","handle":"teecolem6886202","privateProfile":false,"gender":"female","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/5RW3XBKXWMBDNLGF.jpg"}}]}],"summary":"5 likes"},"like":false,"logView":true,"agreeCount":5,"disagreeCount":0,"todo":{"count":10},"saves":{},"user":{"id":"337548","firstName":"Lucky Magazine","handle":"luckymag","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/K5LCPOAUKWFOMV0X.jpg"},"type":"page"}},"photo":{"id":"4ed7b1d1a17c6e17b5ea8298","createdAt":1322758609,"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg","width":450,"height":373,"user":{"id":"337548","firstName":"Lucky Magazine","handle":"luckymag","privateProfile":false,"gender":"none","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/K5LCPOAUKWFOMV0X.jpg"},"type":"page"},"visibility":"public"}}]}}]}]},"phrases":[{"phrase":"five floors","sample":{"entities":[{"indices":[0,11],"type":"keyPhrase"}],"text":"Five floors filled with all the essentials. Be sure to..."},"count":4},{"phrase":"all the supplies","sample":{"entities":[{"indices":[25,41],"type":"keyPhrase"}],"text":"... place is DIY heaven. All the supplies you could imagine. They have an excellent..."},"count":2},{"phrase":"art supply","sample":{"entities":[{"indices":[15,25],"type":"keyPhrase"}],"text":"Five floors of art supply heaven \u2013 they have absolutely everything!..."},"count":2}],"seasonalHours":[],"pageUpdates":{"count":0},"inbox":{"count":0,"items":[]},"attributes":{"groups":[]},"bestPhoto":{"id":"51c75718498e56304ff11a23","createdAt":1372018456,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/2874027_ur6Qbbwyv9k91b3eoUgXfiwj_JF0197YcGq-Zi3-Uqg.jpg","width":720,"height":960,"visibility":"public"}}}}
"""

# %%
# prompt: print json as pretty

import json

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "meta": {
#     "code": 200,
#     "requestId": "6745ac98f9fc4667f6800674"
#   },
#   "notifications": [
#     {
#       "type": "notificationTray",
#       "item": {
#         "unreadCount": 0
#       }
#     }
#   ],
#   "response": {
#     "venue": {
#       "id": "49bbd6c0f964a520f4531fe3",
#       "name": "Pearl Art & Craft Supply",
#       "contact": {
#         "phone": "2124317932",
#         "formattedPhone": "(212) 431-7932",
#         "twitter": "pearlpaint"
#       },
#       "location": {
#         "address": "308 Canal St",
#         "crossStreet": "btwn Broadway & Mercer",
#         "lat": 40.719726415811074,
#         "lng": -74.00247199946715,
#         "radius50": 32,
#         "radius90": 244,
#         "postalCode": "10013",
#         "cc": "US",
#         "city": "New York",
#         "state": "NY",
#         "country": "United States",
#         "formattedAddress": [
#           "308 Canal St (btwn Broadway & Mercer)",
#           "New York, NY 10013",
# ...
