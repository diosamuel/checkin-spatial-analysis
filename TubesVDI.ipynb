# %% [markdown]
# <a href="https://colab.research.google.com/github/diosamuel/checkin-spatial-analysis/blob/main/TubesVDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
NYC = pd.read_csv("https://raw.githubusercontent.com/diosamuel/checkin-spatial-analysis/refs/heads/main/dataset/dataset_TSMC2014_NYC.csv")
TKY = pd.read_csv("https://raw.githubusercontent.com/diosamuel/checkin-spatial-analysis/refs/heads/main/dataset/dataset_TSMC2014_TKY.csv")

# %% [markdown]
# # EDA

# %% [markdown]
# ## Cek Missing Value

# %%
print("NYC")
print(NYC.isnull().sum())
print("TKY")
print(TKY.isnull().sum())
# Out:
# NYC
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64
# TKY
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64

# %% [markdown]
# ## Ubah VenueID ke nama tempat butuh api dari Foursquare
#
# dikasih \$200 dollar tiap bulan
#
# sekali hit api = $000.01 dollar

# %%
# Use boolean indexing for efficient search
matching_rows = NYC[NYC["venueId"] == "42911d00f964a520f5231fe3"]

# Access the results
matching_rows['Days'] = pd.to_datetime(matching_rows['utcTimestamp']).dt.day_name()

matching_rows["Days"].value_counts()
# Out:
# <ipython-input-20-eada76bee5eb>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   matching_rows['Days'] = pd.to_datetime(matching_rows['utcTimestamp']).dt.day_name()
# <ipython-input-20-eada76bee5eb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_rows['Days'] = pd.to_datetime(matching_rows['utcTimestamp']).dt.day_name()
# Days
# Friday       219
# Tuesday      163
# Saturday     162
# Thursday     159
# Wednesday    157
# Monday       152
# Sunday       135
# Name: count, dtype: int64

# %%
# Display all rows of the value counts
pd.set_option("display.max_rows", None)
print(NYC["venueId"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3315515315c8> in <cell line: 2>()
#       1 # Display all rows of the value counts
# ----> 2 pd.set_option("display.max_rows", None)
#       3 print(NYC["venueId"])
#
# NameError: name 'pd' is not defined

# %%
# Display all rows of the value counts
pd.set_option("display.max_rows", None)
print(TKY["venueCategory"].value_counts())
# Out:
# venueCategory
# Train Station                               200428
# Subway                                       41666
# Ramen /  Noodle House                        17303
# Convenience Store                            16833
# Japanese Restaurant                          15680
# Bar                                          14940
# Food & Drink Shop                            14023
# Electronics Store                            10897
# Mall                                         10839
# Coffee Shop                                   8959
# Office                                        8789
# Café                                          8603
# Bridge                                        8162
# Bus Station                                   7965
# Road                                          7528
# Bookstore                                     7418
# Park                                          7247
# Fast Food Restaurant                          6806
# Arcade                                        6153
# College Academic Building                     5981
# Government Building                           5116
# Building                                      5036
# Chinese Restaurant                            4718
# Hobby Shop                                    4648
# Miscellaneous Shop                            4549
# Department Store                              4152
# University                                    3486
# Gym / Fitness Center                          3486
# Other Great Outdoors                          3298
# Medical Center                                3280
# Home (private)                                3106
# Italian Restaurant                            3029
# Light Rail                                    2985
# Restaurant                                    2921
# Clothing Store                                2920
# Airport                                       2902
# Movie Theater                                 2763
# Shrine                                        2696
# Indian Restaurant                             2639
# Convention Center                             2229
# Event Space                                   2209
# Drugstore / Pharmacy                          2041
# Music Venue                                   1909
# Hotel                                         1902
# Diner                                         1851
# Video Store                                   1761
# BBQ Joint                                     1738
# Sushi Restaurant                              1679
# Concert Hall                                  1633
# Plaza                                         1490
# Record Shop                                   1474
# Stadium                                       1469
# Temple                                        1449
# Toy / Game Store                              1401
# Bank                                          1359
# Mobile Phone Shop                             1340
# Post Office                                   1291
# Burger Joint                                  1289
# Bakery                                        1264
# General Entertainment                         1250
# Furniture / Home Store                        1192
# Spa / Massage                                 1100
# Playground                                    1089
# Library                                       1085
# Historic Site                                 1070
# Sculpture Garden                               985
# Deli / Bodega                                  954
# Asian Restaurant                               951
# Art Gallery                                    904
# Smoke Shop                                     902
# Dessert Shop                                   893
# Dumpling Restaurant                            891
# Salon / Barbershop                             825
# Bowling Alley                                  811
# Steakhouse                                     802
# Gas Station / Garage                           792
# School                                         783
# Athletic & Sport                               780
# Parking                                        774
# Sporting Goods Shop                            772
# High School                                    764
# Korean Restaurant                              708
# Bike Shop                                      664
# General College & University                   656
# River                                          621
# Hardware Store                                 613
# Sandwich Place                                 611
# Neighborhood                                   589
# Gift Shop                                      582
# Donut Shop                                     564
# Automotive Shop                                556
# Theater                                        556
# General Travel                                 523
# Art Museum                                     520
# Pizza Place                                    515
# Scenic Lookout                                 509
# French Restaurant                              493
# Other Nightlife                                480
# Residential Building (Apartment / Condo)       472
# American Restaurant                            468
# Thai Restaurant                                467
# Fried Chicken Joint                            444
# Garden                                         432
# Seafood Restaurant                             429
# Arts & Crafts Store                            403
# Student Center                                 363
# Candy Store                                    358
# Spiritual Center                               347
# Video Game Store                               327
# Racetrack                                      305
# Rest Area                                      298
# Beer Garden                                    294
# Laundry Service                                293
# Music Store                                    291
# Camera Store                                   289
# History Museum                                 275
# Museum                                         269
# Food                                           268
# Military Base                                  265
# Gaming Cafe                                    261
# Paper / Office Supplies Store                  258
# Tea Room                                       256
# Soup Place                                     254
# Shop & Service                                 253
# Elementary School                              246
# Science Museum                                 242
# Internet Cafe                                  242
# Ice Cream Shop                                 228
# Ferry                                          226
# Cosmetics Shop                                 220
# Church                                         212
# Travel & Transport                             204
# Casino                                         202
# Trade School                                   196
# Cemetery                                       193
# Spanish Restaurant                             187
# Pool                                           186
# Flower Shop                                    176
# Factory                                        170
# Wings Joint                                    163
# Moving Target                                  160
# Brewery                                        157
# Pet Store                                      157
# Snack Place                                    156
# Community College                              148
# Performing Arts Venue                          146
# Mexican Restaurant                             127
# Embassy / Consulate                            127
# Aquarium                                       112
# German Restaurant                              111
# Car Dealership                                 108
# Nursery School                                 107
# Food Truck                                     105
# Comedy Club                                     99
# Zoo                                             99
# Travel Lounge                                   98
# Gastropub                                       98
# Thrift / Vintage Store                          96
# Jewelry Store                                   95
# Pool Hall                                       92
# Recycling Facility                              92
# Outdoors & Recreation                           90
# Hot Dog Joint                                   88
# Vietnamese Restaurant                           85
# Fair                                            78
# Harbor / Marina                                 76
# Taxi                                            74
# Design Studio                                   69
# Professional & Other Places                     69
# Vegetarian / Vegan Restaurant                   66
# Nightlife Spot                                  64
# Breakfast Spot                                  63
# Middle School                                   63
# Rental Car Location                             62
# Public Art                                      60
# Medical School                                  60
# Dim Sum Restaurant                              58
# Antique Shop                                    56
# Brazilian Restaurant                            55
# Bike Rental / Bike Share                        53
# Caribbean Restaurant                            49
# Tapas Restaurant                                49
# Middle Eastern Restaurant                       49
# Funeral Home                                    46
# Beach                                           44
# Cupcake Shop                                    43
# College Stadium                                 40
# Nail Salon                                      39
# Mediterranean Restaurant                        38
# Bagel Shop                                      36
# Winery                                          35
# Sorority House                                  33
# Board Shop                                      31
# College & University                            30
# Planetarium                                     26
# Australian Restaurant                           26
# Eastern European Restaurant                     24
# Photography Lab                                 24
# Music School                                    24
# Mosque                                          23
# Campground                                      23
# Garden Center                                   23
# Financial or Legal Service                      21
# Turkish Restaurant                              20
# Motorcycle Shop                                 20
# Tanning Salon                                   20
# Salad Place                                     19
# Car Wash                                        19
# Law School                                      17
# Bridal Shop                                     16
# Arts & Entertainment                            13
# Fraternity House                                13
# Scandinavian Restaurant                         12
# Cajun / Creole Restaurant                       12
# Housing Development                             12
# Newsstand                                       11
# Castle                                          11
# Flea Market                                     10
# Taco Place                                       9
# Fish & Chips Shop                                9
# Storage Facility                                 8
# Malaysian Restaurant                             8
# Latin American Restaurant                        8
# City                                             7
# Distillery                                       7
# Animal Shelter                                   7
# Portuguese Restaurant                            7
# South American Restaurant                        6
# African Restaurant                               6
# College Theater                                  6
# Burrito Place                                    6
# Peruvian Restaurant                              5
# Synagogue                                        5
# Cuban Restaurant                                 5
# Ethiopian Restaurant                             4
# Market                                           4
# Moroccan Restaurant                              3
# Swiss Restaurant                                 2
# Argentinian Restaurant                           2
# Mac & Cheese Joint                               2
# Pet Service                                      2
# Southern / Soul Food Restaurant                  1
# Ski Area                                         1
# Arepa Restaurant                                 1
# Gluten-free Restaurant                           1
# Afghan Restaurant                                1
# Falafel Restaurant                               1
# Name: count, dtype: int64

# %%
NYC.iloc[1]
# Out:
# userId                                        979
# venueId                  4a43c0aef964a520c6a61fe3
# venueCategoryId          4bf58dd8d48988d1df941735
# venueCategory                              Bridge
# latitude                                  40.6068
# longitude                               -74.04417
# timezoneOffset                               -240
# utcTimestamp       Tue Apr 03 18:00:25 +0000 2012
# Name: 1, dtype: object

# %%
import requests
venueId = input('VenueID ')
versioning = "%2020231010"
oauth_token = "URKT0K1X0DOFMRKYKKYVVPGI1GIWVBRFCTP005RJFH1JKS0C"
url = f"https://api.foursquare.com/v2/venues/{venueId}/?v={versioning}&oauth_token={oauth_token}"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# VenueID 42911d00f964a520f5231fe3
# {"meta":{"code":200,"requestId":"6745cb01d74f44043608db56"},"notifications":[{"type":"notificationTray","item":{"unreadCount":0}}],"response":{"venue":{"id":"42911d00f964a520f5231fe3","name":"New York Penn Station","contact":{"phone":"2126306401","formattedPhone":"(212) 630-6401"},"location":{"address":"1 Penn Plz","crossStreet":"btwn W 31st & W 33rd St","lat":40.7501992792495,"lng":-73.99274826049805,"labeledLatLngs":[{"label":"display","lat":40.7501992792495,"lng":-73.99274826049805}],"radius50":119,"radius90":1631,"postalCode":"10001","cc":"US","neighborhood":"Chelsea","city":"New York","state":"NY","country":"United States","formattedAddress":["1 Penn Plz (btwn W 31st & W 33rd St)","New York, NY 10001","United States"]},"canonicalUrl":"https:\/\/foursquare.com\/newyorkp5446819","categories":[{"id":"4bf58dd8d48988d129951735","name":"Rail Station","pluralName":"Rail Stations","shortName":"Rail Station","icon":{"prefix":"https:\/\/ss3.4sqi.net\/img\/categories_v2\/travel\/trainstation_","suffix":".png"},"categoryCode":19047,"mapIcon":"fsq-default","primary":true}],"verified":true,"stats":{"tipCount":1672},"url":"https:\/\/www.amtrak.com\/stations\/nyp","likes":{"count":3300,"groups":[{"type":"others","count":3300,"items":[]}],"summary":"3300 Likes"},"like":false,"dislike":false,"ok":false,"header":"According to the Foursquare community, this place is a 5.7 out of 10.","rating":5.7,"ratingColor":"FF9600","ratingSignals":7544,"explanation":"We take into account visits and input from our community. You'll see a number on places based off of ratings and tips written by people like you.","ratingCategory":"poor","deliveryProviders":[{"id":"3310158","url":"https:\/\/www.seamless.com\/menu\/the-acai-station-338-8th-ave-new-york\/3310158?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=3310158","provider":{"name":"seamless","icon":{"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/cap\/","sizes":[40,50],"name":"\/delivery_provider_seamless_20180129.png"}}}],"beenHere":{"count":0,"unconfirmedCount":0,"marked":false,"lastCheckinExpiredAt":0},"photos":{"count":10904,"groups":[{"type":"venue","name":"Venue photos","count":10904,"items":[{"id":"518c3998498ed8cb973c65ae","createdAt":1368144280,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/186827_cLFraUIjzEr6ChGG_Sr8PI7od4RAOQXyOz6A6RS74qw.jpg","width":1920,"height":1440,"user":{"id":"186827","firstName":"Won Sun","lastName":"Parque","handle":"wonsunp7038616","privateProfile":false,"gender":"male","address":"","city":"","state":"","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/186827-DTXC4YFNNIDYQC3V.jpg"}},"visibility":"public"},{"id":"51de9477498ea0baa07914ea","createdAt":1373541495,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/4520788_pu9-XOE9fTEAmS1eg0uV652EsuJVH4wphly6ldx1-i0.jpg","width":1920,"height":1440,"user":{"id":"4520788","firstName":"Sahil","lastName":"Jain","handle":"sahilio","privateProfile":false,"gender":"male","countryCode":"US","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/D1KW5NVN5ATZCIYY.jpg"}},"visibility":"public"},{"id":"518fae07498e6b6a8bf8cfe4","createdAt":1368370695,"source":{"name":"Foursquare for iOS","url":"https:\/\/foursquare.com\/download\/#\/iphone"},"prefix":"https:\/\/fastly.4sqi.net\/img\/general\/","suffix":"\/772811_L-ZHUyrd9pBJ_vcHLA2Bv9Pi8gupSKhENRTGydEyHIM.jpg","width":1918,"height":1434,"user":{"id":"772811","firstName":"Darren","lastName":"Woolley","handle":"darrenp3","privateProfile":false,"gender":"male","address":"","city":"","state":"","followingRelationship":"none","photo":{"prefix":"https:\/\/fastly.4sqi.net\/img\/user\/","suffix":"\/RDHR3IJ3L3FFMECT.jpg"} ...

# %%
# prompt: print json as pretty

import json

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "meta": {
#     "code": 200,
#     "requestId": "6745ac98f9fc4667f6800674"
#   },
#   "notifications": [
#     {
#       "type": "notificationTray",
#       "item": {
#         "unreadCount": 0
#       }
#     }
#   ],
#   "response": {
#     "venue": {
#       "id": "49bbd6c0f964a520f4531fe3",
#       "name": "Pearl Art & Craft Supply",
#       "contact": {
#         "phone": "2124317932",
#         "formattedPhone": "(212) 431-7932",
#         "twitter": "pearlpaint"
#       },
#       "location": {
#         "address": "308 Canal St",
#         "crossStreet": "btwn Broadway & Mercer",
#         "lat": 40.719726415811074,
#         "lng": -74.00247199946715,
#         "radius50": 32,
#         "radius90": 244,
#         "postalCode": "10013",
#         "cc": "US",
#         "city": "New York",
#         "state": "NY",
#         "country": "United States",
#         "formattedAddress": [
#           "308 Canal St (btwn Broadway & Mercer)",
#           "New York, NY 10013",
#           "United States"
#         ]
#       },
#       "canonicalUrl": "https://foursquare.com/v/pearl-art--craft-supply/49bbd6c0f964a520f4531fe3",
#       "categories": [
#         {
#           "id": "4bf58dd8d48988d127951735",
#           "name": "Arts and Crafts Store",
#           "pluralName": "Arts and Crafts Stores",
#           "shortName": "Arts and Crafts Store",
#           "icon": {
#             "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/artstore_",
#             "suffix": ".png"
#           },
#           "categoryCode": 17003,
#           "mapIcon": "fsq-default",
#           "primary": true
#         }
#       ],
#       "verified": false,
#       "stats": {
#         "tipCount": 36
#       },
#       "closed": true,
#       "url": "http://www.pearlpaint.com",
#       "likes": {
#         "count": 72,
#         "groups": [
#           {
#             "type": "others",
#             "count": 72,
#             "items": []
#           }
#         ],
#         "summary": "72 Likes"
#       },
#       "like": false,
#       "dislike": false,
#       "ok": false,
#       "header": "This place doesn't have a rating yet. Once more members of the Foursquare community visit, we can calculate a rating.",
#       "explanation": "We take into account visits and input from our community. You'll see a number on places based off of ratings and tips written by people like you.",
#       "allowMenuUrlEdit": true,
#       "beenHere": {
#         "count": 0,
#         "unconfirmedCount": 0,
#         "marked": false,
#         "lastCheckinExpiredAt": 0
#       },
#       "photos": {
#         "count": 82,
#         "groups": [
#           {
#             "type": "venue",
#             "name": "Venue photos",
#             "count": 82,
#             "items": [
#               {
#                 "id": "51c75718498e56304ff11a23",
#                 "createdAt": 1372018456,
#                 "source": {
#                   "name": "Foursquare for iOS",
#                   "url": "https://foursquare.com/download/#/iphone"
#                 },
#                 "prefix": "https://fastly.4sqi.net/img/general/",
#                 "suffix": "/2874027_ur6Qbbwyv9k91b3eoUgXfiwj_JF0197YcGq-Zi3-Uqg.jpg",
#                 "width": 720,
#                 "height": 960,
#                 "user": {
#                   "id": "2874027",
#                   "firstName": "Zeb",
#                   "lastName": "Holt",
#                   "handle": "zebulonholt",
#                   "privateProfile": false,
#                   "gender": "male",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/H01V5PRGAJFJMD2K.jpg"
#                   }
#                 },
#                 "visibility": "public"
#               },
#               {
#                 "id": "51f03cbf498e6ec7106397c6",
#                 "createdAt": 1374698687,
#                 "source": {
#                   "name": "Foursquare for iOS",
#                   "url": "https://foursquare.com/download/#/iphone"
#                 },
#                 "prefix": "https://fastly.4sqi.net/img/general/",
#                 "suffix": "/2870905_k7r9D8mILFmHjD93n5fNqKVPXlCQGeRmmGFLkF-FOyQ.jpg",
#                 "width": 720,
#                 "height": 960,
#                 "user": {
#                   "id": "2870905",
#                   "firstName": "John",
#                   "lastName": "Proano",
#                   "handle": "johnproano",
#                   "privateProfile": false,
#                   "gender": "male",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/VE4NVEQCGI3OIWGQ.jpg"
#                   }
#                 },
#                 "visibility": "public"
#               },
#               {
#                 "id": "5102aaa8e4b0b319975b4d7c",
#                 "createdAt": 1359129256,
#                 "source": {
#                   "name": "Foursquare for iOS",
#                   "url": "https://foursquare.com/download/#/iphone"
#                 },
#                 "prefix": "https://fastly.4sqi.net/img/general/",
#                 "suffix": "/39399943_gXAWIy8HD-xx2tzxsuelgJP236IAZPQJRP9l9LeHLKM.jpg",
#                 "width": 720,
#                 "height": 960,
#                 "user": {
#                   "id": "39399943",
#                   "firstName": "AndresT5",
#                   "handle": "andrest53699722",
#                   "privateProfile": false,
#                   "gender": "male",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/0GNATKB1CBETNABQ.jpg"
#                   }
#                 },
#                 "visibility": "public"
#               },
#               {
#                 "id": "4dcec7fffd28e64f60f40fd3",
#                 "createdAt": 1305397247,
#                 "source": {
#                   "name": "Foursquare for iOS",
#                   "url": "https://foursquare.com/download/#/iphone"
#                 },
#                 "prefix": "https://fastly.4sqi.net/img/general/",
#                 "suffix": "/MDFU55TIZ0AQVMNQDMIUVRRVPOJB2V20IWHWIH3E1XO5RBD5.jpg",
#                 "width": 537,
#                 "height": 720,
#                 "user": {
#                   "id": "229",
#                   "firstName": "Rick",
#                   "lastName": "Webb",
#                   "handle": "rickwebb",
#                   "privateProfile": false,
#                   "gender": "male",
#                   "address": "",
#                   "city": "",
#                   "state": "",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/_1234222635.jpg"
#                   }
#                 },
#                 "visibility": "public"
#               }
#             ]
#           }
#         ]
#       },
#       "reasons": {
#         "count": 1,
#         "items": [
#           {
#             "summary": "Lots of people like this place",
#             "type": "general",
#             "reasonName": "rawLikesReason"
#           }
#         ]
#       },
#       "createdAt": 1237046976,
#       "hereNow": {
#         "count": 0,
#         "summary": "Nobody here",
#         "groups": []
#       },
#       "tips": {
#         "count": 36,
#         "groups": [
#           {
#             "type": "following",
#             "name": "Tips from people you follow",
#             "count": 0,
#             "items": []
#           },
#           {
#             "type": "others",
#             "name": "All tips",
#             "count": 36,
#             "items": [
#               {
#                 "id": "4d961646d1bca090785655b4",
#                 "createdAt": 1301681734,
#                 "text": "Five floors of art supply heaven \u2013 they have absolutely everything! And the helpful staff will assist you in find everything on your list. Students get 10% off their order.",
#                 "type": "user",
#                 "canonicalUrl": "https://foursquare.com/item/4d961646d1bca090785655b4",
#                 "likes": {
#                   "count": 32,
#                   "groups": [
#                     {
#                       "type": "others",
#                       "count": 32,
#                       "items": []
#                     }
#                   ],
#                   "summary": "32 likes"
#                 },
#                 "like": false,
#                 "logView": true,
#                 "agreeCount": 4,
#                 "disagreeCount": 0,
#                 "todo": {
#                   "count": 3
#                 },
#                 "user": {
#                   "id": "95423",
#                   "firstName": "The Corcoran Group",
#                   "handle": "corcoran_group",
#                   "privateProfile": false,
#                   "gender": "none",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/95423-FGRZ1IMU5FZQMCZB.jpg"
#                   },
#                   "type": "page"
#                 }
#               },
#               {
#                 "id": "49bbd6d770c603bbc3108eb4",
#                 "createdAt": 1237046999,
#                 "text": "The art store has 5 floors: boxes, bags, inks, portfolios - paints, brushes, pastels - paper, sketchbooks, acetate - air brushes, light boxes and more..",
#                 "type": "user",
#                 "canonicalUrl": "https://foursquare.com/item/49bbd6d770c603bbc3108eb4",
#                 "likes": {
#                   "count": 10,
#                   "groups": [
#                     {
#                       "type": "others",
#                       "count": 10,
#                       "items": []
#                     }
#                   ],
#                   "summary": "10 likes"
#                 },
#                 "like": false,
#                 "logView": true,
#                 "agreeCount": 2,
#                 "disagreeCount": 0,
#                 "todo": {
#                   "count": 1
#                 },
#                 "user": {
#                   "id": "1726",
#                   "firstName": "adafruit",
#                   "lastName": "fried & torrone",
#                   "handle": "adafruit",
#                   "privateProfile": false,
#                   "gender": "none",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/1726_1236972007.jpg"
#                   }
#                 }
#               },
#               {
#                 "id": "4fe0de79e4b0bd44612a99d5",
#                 "createdAt": 1340137081,
#                 "text": "In the heart of NYC\u2019s Chinatown, Pearl has everything an artist or crafter needs to create! \u2013 Meg Paska",
#                 "type": "user",
#                 "canonicalUrl": "https://foursquare.com/item/4fe0de79e4b0bd44612a99d5",
#                 "likes": {
#                   "count": 5,
#                   "groups": [
#                     {
#                       "type": "others",
#                       "count": 5,
#                       "items": [
#                         {
#                           "id": "57942091",
#                           "firstName": "eth",
#                           "handle": "eth9200322",
#                           "privateProfile": false,
#                           "gender": "male",
#                           "address": "",
#                           "city": "",
#                           "state": "",
#                           "countryCode": "DE",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"
#                           }
#                         },
#                         {
#                           "id": "33403266",
#                           "firstName": "Justine",
#                           "handle": "tinaroy59",
#                           "privateProfile": false,
#                           "gender": "female",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/HUQJMDBOLG24V0HF.jpg"
#                           }
#                         },
#                         {
#                           "id": "126884",
#                           "firstName": "danielle",
#                           "handle": "danielleabes",
#                           "privateProfile": false,
#                           "gender": "female",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/NM5VE4RU52MTFQKE.jpg"
#                           }
#                         },
#                         {
#                           "id": "43910248",
#                           "firstName": "Rachel",
#                           "lastName": "Faucett",
#                           "handle": "followcharlotte",
#                           "privateProfile": false,
#                           "gender": "female",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/4UNOTPJUIFKROTYS.jpg"
#                           }
#                         }
#                       ]
#                     }
#                   ],
#                   "summary": "5 likes"
#                 },
#                 "like": false,
#                 "logView": true,
#                 "agreeCount": 5,
#                 "disagreeCount": 0,
#                 "todo": {
#                   "count": 2
#                 },
#                 "user": {
#                   "id": "1596715",
#                   "firstName": "Bing",
#                   "handle": "bing",
#                   "privateProfile": false,
#                   "gender": "none",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/ZVCLYGVA33EMBIYB.jpg"
#                   },
#                   "type": "page"
#                 }
#               },
#               {
#                 "id": "4ed7b1d0be7b356716f5cf14",
#                 "createdAt": 1322758608,
#                 "text": "Go to Pearl Paint, pick up some watercolors, take a walk to Battery Park and paint the skyline, Lady Liberty and Ellis Island as boats sail by.",
#                 "type": "user",
#                 "canonicalUrl": "https://foursquare.com/item/4ed7b1d0be7b356716f5cf14",
#                 "photo": {
#                   "id": "4ed7b1d1a17c6e17b5ea8298",
#                   "createdAt": 1322758609,
#                   "source": {
#                     "name": "Foursquare Web",
#                     "url": "https://foursquare.com"
#                   },
#                   "prefix": "https://fastly.4sqi.net/img/general/",
#                   "suffix": "/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg",
#                   "width": 450,
#                   "height": 373,
#                   "visibility": "public"
#                 },
#                 "photos": [
#                   {
#                     "id": "4ed7b1d1a17c6e17b5ea8298",
#                     "createdAt": 1322758609,
#                     "source": {
#                       "name": "Foursquare Web",
#                       "url": "https://foursquare.com"
#                     },
#                     "prefix": "https://fastly.4sqi.net/img/general/",
#                     "suffix": "/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg",
#                     "width": 450,
#                     "height": 373,
#                     "visibility": "public"
#                   }
#                 ],
#                 "photourl": "https://fastly.4sqi.net/img/general/original/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg",
#                 "likes": {
#                   "count": 5,
#                   "groups": [
#                     {
#                       "type": "others",
#                       "count": 5,
#                       "items": [
#                         {
#                           "id": "49936356",
#                           "firstName": "Budak",
#                           "lastName": "Pokan\ud83d\udc82",
#                           "handle": "budak1463236",
#                           "privateProfile": false,
#                           "gender": "male",
#                           "address": "",
#                           "city": "",
#                           "state": "",
#                           "countryCode": "SG",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/49936356_d7tEwjIa_DmddEssVOIg01esf1ZewuXpz5x1Y6GqxAot0fJjl4Xh8cUULyiV-U0Z408O8waSm.jpg"
#                           }
#                         },
#                         {
#                           "id": "36834369",
#                           "firstName": "Cman",
#                           "lastName": "Finn",
#                           "handle": "cman_0412",
#                           "privateProfile": false,
#                           "gender": "male",
#                           "address": "",
#                           "city": "",
#                           "state": "",
#                           "countryCode": "MY",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/36834369-SMLGRYWE1N1IAESS.jpg"
#                           }
#                         },
#                         {
#                           "id": "57942091",
#                           "firstName": "eth",
#                           "handle": "eth9200322",
#                           "privateProfile": false,
#                           "gender": "male",
#                           "address": "",
#                           "city": "",
#                           "state": "",
#                           "countryCode": "DE",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"
#                           }
#                         },
#                         {
#                           "id": "38387096",
#                           "firstName": "\"Tee Coleman\"",
#                           "handle": "teecolem6886202",
#                           "privateProfile": false,
#                           "gender": "female",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/5RW3XBKXWMBDNLGF.jpg"
#                           }
#                         }
#                       ]
#                     }
#                   ],
#                   "summary": "5 likes"
#                 },
#                 "like": false,
#                 "logView": true,
#                 "agreeCount": 5,
#                 "disagreeCount": 0,
#                 "todo": {
#                   "count": 10
#                 },
#                 "user": {
#                   "id": "337548",
#                   "firstName": "Lucky Magazine",
#                   "handle": "luckymag",
#                   "privateProfile": false,
#                   "gender": "none",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/K5LCPOAUKWFOMV0X.jpg"
#                   },
#                   "type": "page"
#                 }
#               }
#             ]
#           }
#         ]
#       },
#       "shortUrl": "http://4sq.com/2UcSiI",
#       "timeZone": "America/New_York",
#       "listed": {
#         "count": 83,
#         "groups": [
#           {
#             "type": "others",
#             "name": "Lists from other people",
#             "count": 83,
#             "items": [
#               {
#                 "id": "4ed7a30f29c216b5c8d05810",
#                 "name": "Sophie's Favorite Holiday Spots in NYC",
#                 "description": "The Super Adventures of Sophie and the City by Kelly Florio Kasouf is a children's book about Kasouf's childhood growing up in the halls of Conde Nast. She picked her favorite holiday spots to visit.",
#                 "type": "others",
#                 "user": {
#                   "id": "337548",
#                   "firstName": "Lucky Magazine",
#                   "handle": "luckymag",
#                   "privateProfile": false,
#                   "gender": "none",
#                   "countryCode": "US",
#                   "followingRelationship": "none",
#                   "photo": {
#                     "prefix": "https://fastly.4sqi.net/img/user/",
#                     "suffix": "/K5LCPOAUKWFOMV0X.jpg"
#                   },
#                   "type": "page"
#                 },
#                 "editable": false,
#                 "public": true,
#                 "collaborative": false,
#                 "url": "/luckymag/list/sophies-favorite-holiday-spots-in-nyc",
#                 "canonicalUrl": "https://foursquare.com/luckymag/list/sophies-favorite-holiday-spots-in-nyc",
#                 "createdAt": 1322754831,
#                 "updatedAt": 1377042169,
#                 "photo": {
#                   "id": "4ed7accda17c6e17b5e9ccef",
#                   "createdAt": 1322757325,
#                   "prefix": "https://fastly.4sqi.net/img/general/",
#                   "suffix": "/HPCHEWUSIBU4CPJGQQPZWZPOBF2SKP30KECLIX0T0NG043AV.jpg",
#                   "width": 366,
#                   "height": 465,
#                   "user": {
#                     "id": "337548",
#                     "firstName": "Lucky Magazine",
#                     "handle": "luckymag",
#                     "privateProfile": false,
#                     "gender": "none",
#                     "countryCode": "US",
#                     "followingRelationship": "none",
#                     "photo": {
#                       "prefix": "https://fastly.4sqi.net/img/user/",
#                       "suffix": "/K5LCPOAUKWFOMV0X.jpg"
#                     },
#                     "type": "page"
#                   },
#                   "visibility": "public"
#                 },
#                 "logView": true,
#                 "followers": {
#                   "count": 194
#                 },
#                 "listItems": {
#                   "count": 22,
#                   "items": [
#                     {
#                       "id": "t4ed7b1d0be7b356716f5cf14",
#                       "createdAt": 1322755445,
#                       "tip": {
#                         "id": "4ed7b1d0be7b356716f5cf14",
#                         "createdAt": 1322758608,
#                         "text": "Go to Pearl Paint, pick up some watercolors, take a walk to Battery Park and paint the skyline, Lady Liberty and Ellis Island as boats sail by.",
#                         "type": "user",
#                         "canonicalUrl": "https://foursquare.com/item/4ed7b1d0be7b356716f5cf14",
#                         "likes": {
#                           "count": 5,
#                           "groups": [
#                             {
#                               "type": "others",
#                               "count": 5,
#                               "items": [
#                                 {
#                                   "id": "49936356",
#                                   "firstName": "Budak",
#                                   "lastName": "Pokan\ud83d\udc82",
#                                   "handle": "budak1463236",
#                                   "privateProfile": false,
#                                   "gender": "male",
#                                   "address": "",
#                                   "city": "",
#                                   "state": "",
#                                   "countryCode": "SG",
#                                   "followingRelationship": "none",
#                                   "photo": {
#                                     "prefix": "https://fastly.4sqi.net/img/user/",
#                                     "suffix": "/49936356_d7tEwjIa_DmddEssVOIg01esf1ZewuXpz5x1Y6GqxAot0fJjl4Xh8cUULyiV-U0Z408O8waSm.jpg"
#                                   }
#                                 },
#                                 {
#                                   "id": "36834369",
#                                   "firstName": "Cman",
#                                   "lastName": "Finn",
#                                   "handle": "cman_0412",
#                                   "privateProfile": false,
#                                   "gender": "male",
#                                   "address": "",
#                                   "city": "",
#                                   "state": "",
#                                   "countryCode": "MY",
#                                   "followingRelationship": "none",
#                                   "photo": {
#                                     "prefix": "https://fastly.4sqi.net/img/user/",
#                                     "suffix": "/36834369-SMLGRYWE1N1IAESS.jpg"
#                                   }
#                                 },
#                                 {
#                                   "id": "57942091",
#                                   "firstName": "eth",
#                                   "handle": "eth9200322",
#                                   "privateProfile": false,
#                                   "gender": "male",
#                                   "address": "",
#                                   "city": "",
#                                   "state": "",
#                                   "countryCode": "DE",
#                                   "followingRelationship": "none",
#                                   "photo": {
#                                     "prefix": "https://fastly.4sqi.net/img/user/",
#                                     "suffix": "/57942091_al0s4kw9_VvyqFJg0VZUPJEohihGS0xbP7oc4lIN0LGhi4EuIoLnX0_MeLY2KUMx0ZLNVLlj3.jpg"
#                                   }
#                                 },
#                                 {
#                                   "id": "38387096",
#                                   "firstName": "\"Tee Coleman\"",
#                                   "handle": "teecolem6886202",
#                                   "privateProfile": false,
#                                   "gender": "female",
#                                   "countryCode": "US",
#                                   "followingRelationship": "none",
#                                   "photo": {
#                                     "prefix": "https://fastly.4sqi.net/img/user/",
#                                     "suffix": "/5RW3XBKXWMBDNLGF.jpg"
#                                   }
#                                 }
#                               ]
#                             }
#                           ],
#                           "summary": "5 likes"
#                         },
#                         "like": false,
#                         "logView": true,
#                         "agreeCount": 5,
#                         "disagreeCount": 0,
#                         "todo": {
#                           "count": 10
#                         },
#                         "saves": {},
#                         "user": {
#                           "id": "337548",
#                           "firstName": "Lucky Magazine",
#                           "handle": "luckymag",
#                           "privateProfile": false,
#                           "gender": "none",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/K5LCPOAUKWFOMV0X.jpg"
#                           },
#                           "type": "page"
#                         }
#                       },
#                       "photo": {
#                         "id": "4ed7b1d1a17c6e17b5ea8298",
#                         "createdAt": 1322758609,
#                         "prefix": "https://fastly.4sqi.net/img/general/",
#                         "suffix": "/10X3YK4VAC42FKOEUSE4S3LPPLRBOS2BWH0SMGGTCVXTUREN.jpg",
#                         "width": 450,
#                         "height": 373,
#                         "user": {
#                           "id": "337548",
#                           "firstName": "Lucky Magazine",
#                           "handle": "luckymag",
#                           "privateProfile": false,
#                           "gender": "none",
#                           "countryCode": "US",
#                           "followingRelationship": "none",
#                           "photo": {
#                             "prefix": "https://fastly.4sqi.net/img/user/",
#                             "suffix": "/K5LCPOAUKWFOMV0X.jpg"
#                           },
#                           "type": "page"
#                         },
#                         "visibility": "public"
#                       }
#                     }
#                   ]
#                 }
#               }
#             ]
#           }
#         ]
#       },
#       "phrases": [
#         {
#           "phrase": "five floors",
#           "sample": {
#             "entities": [
#               {
#                 "indices": [
#                   0,
#                   11
#                 ],
#                 "type": "keyPhrase"
#               }
#             ],
#             "text": "Five floors filled with all the essentials. Be sure to..."
#           },
#           "count": 4
#         },
#         {
#           "phrase": "all the supplies",
#           "sample": {
#             "entities": [
#               {
#                 "indices": [
#                   25,
#                   41
#                 ],
#                 "type": "keyPhrase"
#               }
#             ],
#             "text": "... place is DIY heaven. All the supplies you could imagine. They have an excellent..."
#           },
#           "count": 2
#         },
#         {
#           "phrase": "art supply",
#           "sample": {
#             "entities": [
#               {
#                 "indices": [
#                   15,
#                   25
#                 ],
#                 "type": "keyPhrase"
#               }
#             ],
#             "text": "Five floors of art supply heaven \u2013 they have absolutely everything!..."
#           },
#           "count": 2
#         }
#       ],
#       "seasonalHours": [],
#       "pageUpdates": {
#         "count": 0
#       },
#       "inbox": {
#         "count": 0,
#         "items": []
#       },
#       "attributes": {
#         "groups": []
#       },
#       "bestPhoto": {
#         "id": "51c75718498e56304ff11a23",
#         "createdAt": 1372018456,
#         "source": {
#           "name": "Foursquare for iOS",
#           "url": "https://foursquare.com/download/#/iphone"
#         },
#         "prefix": "https://fastly.4sqi.net/img/general/",
#         "suffix": "/2874027_ur6Qbbwyv9k91b3eoUgXfiwj_JF0197YcGq-Zi3-Uqg.jpg",
#         "width": 720,
#         "height": 960,
#         "visibility": "public"
#       }
#     }
#   }
# }

# %%
NYC_userid_counts = NYC['userId'].value_counts()
NYC_userid_counts.head(5)
# Out:
# userId
# 293    2697
# 185    2079
# 354    2061
# 315    1682
# 84     1376
# Name: count, dtype: int64

# %% [markdown]
# # Ambil Nama by UserID

# %%
from bs4 import BeautifulSoup
API_PATH = f"http://foursquare.com/user/979"
response = requests.get(API_PATH)

soup = BeautifulSoup(response.text, 'html.parser')
name_element = soup.find(class_="name")
if name_element:
    name = name_element.text
    print(name)
# Out:
# Ilkka Järstä

# %% [markdown]
# 1. Dimana saja tempat yang sering dikunjungi di kota New York dan Tokyo?
# [visualisasi peta] ahmet
# 2. Pada waktu kapan saja tempat atau area tersebut mulai sibuk?
# [kalau per hari - visualisasi barplot]
# 3. Dalam hitungan per waktu, kategori tempat apa yang orang sering kunjungi?(per hari, per bulan, per minggu, dll)
# [visualisasi barplot]
# 4. Apakah ada hubungan antara lokasi geografis dengan frekuensi kunjungan masyarakat? [visualisasi heatmap]
# 5. Bagaimana perbedaan waktu kunjungan pada kategori tempat yg sama di kedua kota?  (spend time, atau pagi/siang/malam antara kedua tempat tsb) [barplot]
#
#
# kategori yg bisa dianalisis
# 1. Tempat Makan/Restoran
# 2. Transportasi Umum
# 3. Wisata
# 4. Belanja (Entertainment)
# 5. Public Service & Area
# 6. Residental (Home & Neighborhood)
# 5. Working Place
